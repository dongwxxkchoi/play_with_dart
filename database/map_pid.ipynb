# %%
import sqlite3
import pandas as pd
import os
import argparse
import asyncio
from tqdm.notebook import tqdm
from db import DB

# %%
db = DB("dart_corp.db")
db.open_connection()

# %%
folder_path = "../data"
year = 2023
quarter = 1
exctv_file_name = f"2021_2022-상장사-drop_dup-{2023}년도-{1}분기.csv"
corp_file_name = f"2021_2022-상장사-drop_dup.csv"
exctv_file_path = os.path.join(folder_path, exctv_file_name)
corp_file_path = os.path.join(folder_path, corp_file_name)

drop_cols = ['발행주식총수', '시가총액', '종가', '연도']
exctv_df = pd.read_csv(exctv_file_path, encoding='utf-8', dtype=object).drop(columns=drop_cols)
exctv_df['기간'] = str(year) + "_" + str(quarter) 
corp_df = pd.read_csv(corp_file_path, encoding='utf-8', dtype=object, index_col=0).drop(columns=['연도'])

# %%
exctv_df
# Out:
#          종목코드      종목명    시장구분 corp_code   이름       생년월일 성별    직위  등기여부 상근여부  \
# 0      005930     삼성전자   KOSPI  00126380  한종희  1962년 03월  남   부회장  사내이사   상근
# 1      005930     삼성전자   KOSPI  00126380  허은녕  1964년 08월  남    이사  사외이사  비상근
# 2      005930     삼성전자   KOSPI  00126380  유명희  1967년 06월  여    이사  사외이사  비상근
# 3      005930     삼성전자   KOSPI  00126380  경계현  1963년 03월  남    사장  사내이사   상근
# 4      005930     삼성전자   KOSPI  00126380  노태문  1968년 09월  남    사장  사내이사   상근
# ...       ...      ...     ...       ...  ...        ... ..   ...   ...  ...
# 29733  114570  지스마트글로벌  KOSDAQ  00673976  박승만  1946년 08월  남    감사    감사  비상근
# 29734  240340     인터코스   KONEX  01117592  김주덕  1970년 11월  남  대표이사  사내이사   상근
# 29735  240340     인터코스   KONEX  01117592  김경렬  1970년 04월  남  관리이사  사내이사   상근
# 29736  240340     인터코스   KONEX  01117592  김봉수  1970년 01월  남  영업이사  사내이사   상근
# 29737  240340     인터코스   KONEX  01117592  임성종  1984년 12월  남    감사    감사  비상근
#
#                                담당업무 최대주주와의관계   재직기간          임기만료일      기간
# 0           ㆍ대표이사   (DX 부문 경영전반 총괄)   계열회사임원   37개월  2026년 03월 15일  2023_1
# 1      ㆍ사외이사후보추천위원회 위원ㆍ지속가능경영위원회 위원   계열회사임원    5개월  2025년 11월 02일  2023_1
# 2      ㆍ사외이사후보추천위원회 위원ㆍ지속가능경영위원회 위원   계열회사임원    5개월  2025년 11월 02일  2023_1
# 3           ㆍ대표이사   (DS 부문 경영전반 총괄)   계열회사임원   13개월  2025년 03월 15일  2023_1
# 4                           ㆍMX사업부장   계열회사임원   13개월  2025년 03월 15일  2023_1
# ...                             ...      ...    ...            ...     ...
# 29733                            감사       없음  1년2개월  2023년 10월 29일  2023_1
# 29734                          경영총괄     대표이사      -  2024년 03월 29일  2023_1
# 29735                            총무        -      -  2025년 03월 31일  2023_1
# 29736                            영업    특수관계자      -  2024년 03월 29일  2023_1
# 29737                            감사        -      -  2025년 03월 31일  2023_1
#
# [29738 rows x 15 columns]

# %%
corp_df
# Out:
#         종목코드       종목명    시장구분 corp_code
# 0     005930      삼성전자   KOSPI  00126380
# 1     373220  LG에너지솔루션   KOSPI  01515323
# 2     207940  삼성바이오로직스   KOSPI  00877059
# 3     000660    SK하이닉스   KOSPI  00164779
# 4     051910      LG화학   KOSPI  00356361
# ...      ...       ...     ...       ...
# 2615  240340      인터코스   KONEX  01117592
# 2616  329020      오션스톤   KONEX  01388631
# 2617  225850       미애부   KONEX  00866594
# 2618  221610     자안바이오  KOSDAQ  00493431
# 2619  225860   엠앤씨생명과학   KONEX  01116274
#
# [2620 rows x 4 columns]

# %% [markdown]
# ## DB TABLE 생성

# %%
create_table_query_corp = '''CREATE TABLE corp (
                            corp_code TEXT PRIMARY KEY,
                            stock_code TEXT,
                            stock_name TEXT,
                            market TEXT )
                        '''

create_table_query_exc_list = '''CREATE TABLE executive_list (
                        corp_code TEXT,
                        pid TEXT,
                        year INTEGER,
                        quarter INTEGER,
                        position TEXT,
                        registration TEXT,
                        full_time TEXT,
                        job TEXT,
                        relationship_with_shareholder TEXT,
                        employ_duration TEXT,
                        expire_date TEXT,
                        PRIMARY KEY (corp_code, pid, year, quarter),
                        CONSTRAINT corp_code_fk FOREIGN KEY(corp_code) REFERENCES corp(corp_code),
                        CONSTRAINT pid_fk FOREIGN KEY(pid) REFERENCES executive_details(pid)
                        );
                        '''
create_table_query_exc_det = '''CREATE TABLE executive_details (
                        pid TEXT PRIMARY KEY,
                        name TEXT,
                        birth_date TEXT,
                        sex TEXT);
                        '''

# %%
db.run_query(create_table_query_corp)
db.run_query(create_table_query_exc_det)
db.run_query(create_table_query_exc_list)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 db.run_query(create_table_query_corp)
#       2 db.run_query(create_table_query_exc_det)
#       3 db.run_query(create_table_query_exc_list)
#
# File ~/dongwook/pythonProject/database/db.py:25, in DB.run_query(self, query)
#      24 def run_query(self, query: str):
# ---> 25     self.__cursor.execute(query)
#
# OperationalError: table corp already exists

# %%
print(db.run_fetch("SELECT name FROM sqlite_master WHERE type='table';"))
# Out:
# [('corp',), ('executive_details',), ('executive_list',)]

# %% [markdown]
# ## INSERT datas

# %%
insert_query_corp = '''INSERT INTO corp
                    (corp_code, stock_code, stock_name, market) 
                    VALUES (?, ?, ?, ?)'''

insert_query_exc_det = '''INSERT INTO executive_details
                        (pid, name, birth_date, sex) 
                        VALUES (?, ?, ?, ?)'''

insert_query_exc_list = '''INSERT INTO executive_list
                        (corp_code, pid, year, quarter, position, 
                        registration, full_time, job, relationship_with_shareholder, 
                        employ_duration, expire_date) 
                        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)'''

# %% [markdown]
# #### INSERT TO corp

# %%
corp_df.to_records(index=False)
# Out:
# rec.array([('005930', '삼성전자', 'KOSPI', '00126380'),
#            ('373220', 'LG에너지솔루션', 'KOSPI', '01515323'),
#            ('207940', '삼성바이오로직스', 'KOSPI', '00877059'), ...,
#            ('225850', '미애부', 'KONEX', '00866594'),
#            ('221610', '자안바이오', 'KOSDAQ', '00493431'),
#            ('225860', '엠앤씨생명과학', 'KONEX', '01116274')],
#           dtype=[('종목코드', 'O'), ('종목명', 'O'), ('시장구분', 'O'), ('corp_code', 'O')])

# %%
db.run_query("DELETE FROM corp")
corp_df = corp_df[['corp_code', '종목코드', '종목명', '시장구분']]
for row in corp_df.to_records(index=False):
    
    db.run_query_with_params(insert_query_corp, row)

# %% [markdown]
# #### INSERT TO exc_det (map pid)

# %%
def map_pid(df: pd.DataFrame, db: DB):
    db.run_query("DELETE FROM executive_details")
    idtfy_df = df[:][['이름', '생년월일', '성별']]
    idtfy_df = idtfy_df.drop_duplicates()
    
    query = "SELECT PID FROM executive_details WHERE (name = ? and birth_date = ? and sex = ?)"
    for pid, row in idtfy_df.iterrows():
        
        params = list(row.values)
        res = db.run_fetch_with_params(query, params)
        if res is not None:
            params = [str(pid).zfill(6)] + [x for x in params]
            params[2] = params[2].replace(" ", "")
            db.run_query_with_params(insert_query_exc_det, params) 

map_pid(exctv_df, db)

# %%
print(db.run_fetch("SELECT * FROM executive_details"))
# Out:
# [('000000', '한종희', '1962년03월', '남'), ('000001', '허은녕', '1964년08월', '남'), ('000002', '유명희', '1967년06월', '여'), ('000003', '경계현', '1963년03월', '남'), ('000004', '노태문', '1968년09월', '남'), ('000005', '박학규', '1964년11월', '남'), ('000006', '이정배', '1967년02월', '남'), ('000007', '김한조', '1956년07월', '남'), ('000008', '김선욱', '1952년12월', '여'), ('000009', '김종훈', '1960년08월', '남'), ('000010', '김준성', '1967년10월', '남'), ('000011', '권영수', '1957년02월', '남'), ('000012', '이방수', '1958년11월', '남'), ('000013', '장성훈', '1979년01월', '남'), ('000014', '장승권', '1969년07월', '남'), ('000015', '장응진', '1968년11월', '남'), ('000016', '정왕모', '1971년10월', '남'), ('000017', '정원희', '1975년09월', '남'), ('000018', '정하상', '1971년01월', '남'), ('000019', '정혁성', '1973년07월', '남'), ('000020', '정회국', '1977년08월', '남'), ('000021', '조상연', '1977년02월', '남'), ('000022', '최대식', '1975년03월', '남'), ('000023', '김수령', '1962년03월', '남'), ('000024', '최상훈', '1972년02월', '남'), ('000025', '최성훈', '1968년12월', '남'), ('000026', '최세호', '1966년06월', '남'), ('000027', '최유라', '1976년12월', '여'), ('000028', '최은아', '1979년11월', '여'), ('000029', '최재용', '1969년10월', '남'), ('000030', '최제원', '1973년01월', '남'), ('000031', '최해원', '1972년01월', '남'), ('000032', '한동훈', '1979년09월', '남'), ('000033', '허양현', '1969년05월', '남'), ('000034', '박진원', '1967년04월', '남'), ('000035', '허연호', '1966년09월', '남'), ('000036', '현오영', '1968년07월', '남'), ('000037', '홍우평', '1963년01월', '남'), ('000038', '홍정진', '1969년01월', '남'), ('000039', '서원준', '1967년10월', '남'), ('000040', '신영준', '1970년06월', '남'), ('000041', '이혁재', '1966년04월', '남'), ('000042', '전수호', '1962년10월', '남'), ('000043', '정근창', '1967년12월', '남'), ('000044', '최석원', '1966년02월', '남'), ('000045', '김근태', '1960년05월', '남'), ('000046', '권봉석', '1963년09월', '남'), ('000047', '김기수', '1969년03월', '남'), ('000048', '김동수', '1960년07월', '남'), ('000049', '노세원', '1967년09월', '남'), ('000050', '변경석', '1972년02월', '남'), ('000051', '성환두', '1965년10월', '남'), ('000052', '손창완', '1970년01월', '남'), ('000053', '이득중', '1961년06월', '남'), ('000054', '이장하', '1968년08월', '남'), ('000055', '장승세', '1973년04월', '남'), ('000056', '정재한', '1968년02월', '남'), ('000057', '이창실', '1964년12월', '남'), ('000058', '조지훈', '1968년11월', '남'), ('000059', '최승돈', '1972년05월', '남'), ('000060', '한웅재', '1970년10월', '남'), ('000061', 'Denny Thiemig', '1980년10월', '남'), ('000062', '강경원', '1974년02월', '남'), ('000063', '강달모', '1975년06월', '남'), ('000064', '강성모', '1972년08월', '남'), ('000065', '강호석', '1965년10월', '남'), ('000066', '구자훈', '1968년08월', '남'), ('000067', '권종훈', '1971년10월', '남'), ('000068', '박진규', '1966년04월', '남'), ('000069', '김경훈', '1972년01월', '남'), ('000070', '김규성', '1968년02월', '남'), ('000071', '김기웅', '1973년11월', '남'), ('000072', '김기태', '1972년02월', '남'), ('000073', '김남호', '1972년10월', '남'), ('000074', '김민교', '1968년03월', '남'), ('000075', '김범재', '1971년12월', '남'), ('000076', '김병수', '1975년07월', '남'), ('000077', '김병습', '1973년01월', '남'), ('000078', '김석구', '1973년12월', '남'), ('000079', '신미남', '1961년12월', '여'), ('000080', '김영득', '1968년10월', '남'), ('000081', '김영훈', '1978년06월', '남'), ('000082', '김장성', '1964년05월', '남'), ('000083', '김재길', '1967년02월', '남'), ('000084', '김정수', '1968년04월', '남'), ('000085', '김제영', '1972년01월', '남'), ('000086', '김종훈', '1972년11월', '남'), ('000087', '김진경', '1973년01월', '여'), ('000088', '김형식', '1973년12월', '남'), ('000089', '나균일', '1966년01월', '남'), ('000090', '여미숙', '1966년02월', '여'), ('000091', '나희관', '1974년02월', '남'), ('000092', '남경현', '1973년05월', '남'), ('000093', '남주현', '1974년08월', '여'), ('000094', '류덕현', '1974년06월', '남'), ('000095', '박재홍', '1975년03월', '남'), ('000096', '박진용', '1970년08월', '남'), ('000097', '박철희', '1970년02월', '남'), ('000098', '박필규', '1973년12월', '남'), ('000099', '성기은', '1976년01월', '남'), ('000100', '손춘기', '1969년03월', '남'), ('000101', '한승수', '1970년02월', '남'), ('000102', '송무강', '1972년03월', '남'), ('000103', '송준혁', '1974년07월', '남'), ('000104', '송찬규', '1973년03월', '남'), ('000105', '신기창', '1972년04월', '남'), ('000106', '신동환', '1970년09월', '남'), ('000107', '신용인', '1969년11월', '남'), ('000108', '신장환', '1971년08월', '남'), ('000109', '신준영', '1975년05월', '남'), ('000110', '안민규', '1968년10월', ...

# %% [markdown]
# #### INSERT TO exctv_list

# %% [markdown]
# ###### update exctv_df pid and will insert to executive_list_df

# %%
query = f"SELECT pid FROM executive_details WHERE name = ? and birth_date = ? and sex = ?"

exctv_det_df = exctv_df[:][['이름','생년월일','성별']]
exctv_det_df['생년월일'] = exctv_det_df['생년월일'].apply(lambda x: x.replace(" ", ""))

for pid, row in exctv_det_df.iterrows():
    params = row[['이름', '생년월일', '성별']].values
    res = db.run_fetch_with_params(query, params)
    if len(res) > 0:
        exctv_df.loc[pid, 'pid'] = str(res[0][0]).zfill(6)

# %%
exctv_df.head()
# Out:
#      종목코드   종목명   시장구분 corp_code   이름       생년월일 성별   직위  등기여부 상근여부  \
# 0  005930  삼성전자  KOSPI  00126380  한종희  1962년 03월  남  부회장  사내이사   상근
# 1  005930  삼성전자  KOSPI  00126380  허은녕  1964년 08월  남   이사  사외이사  비상근
# 2  005930  삼성전자  KOSPI  00126380  유명희  1967년 06월  여   이사  사외이사  비상근
# 3  005930  삼성전자  KOSPI  00126380  경계현  1963년 03월  남   사장  사내이사   상근
# 4  005930  삼성전자  KOSPI  00126380  노태문  1968년 09월  남   사장  사내이사   상근
#
#                            담당업무 최대주주와의관계  재직기간          임기만료일      기간     pid
# 0       ㆍ대표이사   (DX 부문 경영전반 총괄)   계열회사임원  37개월  2026년 03월 15일  2023_1  000000
# 1  ㆍ사외이사후보추천위원회 위원ㆍ지속가능경영위원회 위원   계열회사임원   5개월  2025년 11월 02일  2023_1  000001
# 2  ㆍ사외이사후보추천위원회 위원ㆍ지속가능경영위원회 위원   계열회사임원   5개월  2025년 11월 02일  2023_1  000002
# 3       ㆍ대표이사   (DS 부문 경영전반 총괄)   계열회사임원  13개월  2025년 03월 15일  2023_1  000003
# 4                       ㆍMX사업부장   계열회사임원  13개월  2025년 03월 15일  2023_1  000004

# %%
exctv_list_df = exctv_df[:]
exctv_list_df = exctv_list_df.drop(columns=['이름', '생년월일', '성별'])

db.run_query("DELETE FROM executive_list")

for i, row in exctv_list_df.iterrows():
    params = row[['corp_code', 'pid']].values.tolist()
    params2 = row['기간'].split('_')
    params3 = row[['직위', '등기여부', '상근여부', '담당업무', '최대주주와의관계', '재직기간', '임기만료일']].values.tolist()
    params.extend(params2)
    params.extend(params3)
    try:
        db.run_query_with_params(insert_query_exc_list, params)
    except Exception as e:
        print(db.run_fetch_with_params("SELECT * FROM executive_list WHERE pid = ?", [params[1]]))
        print(db.run_fetch_with_params("SELECT * FROM executive_details WHERE pid = ?", [params[1]]))
        print(db.run_fetch_with_params("SELECT * FROM corp WHERE corp_code = ?", [params[0]]))
        print(params, end="\n------------------------------------------------------------------------\n")
# Out:
# [('00154462', '003702', 2023, 1, '경영자', '미등기', '상근', '회장실', '-', '2015.01.01~', '-')]
# [('003702', '이준식', '1970년02월', '남')]
# [('00154462', '002790', '아모레G', 'KOSPI')]
# ['00154462', '003702', '2023', '1', '경영자', '미등기', '상근', '비서실', '-', '2015.01.01~', '-']
# ------------------------------------------------------------------------
# [('00154462', '003703', 2023, 1, '경영자', '미등기', '상근', '전략기획', '계열회사 임원', '2014.09.01 ~', '-')]
# [('003703', '이진표', '1977년11월', '남')]
# [('00154462', '002790', '아모레G', 'KOSPI')]
# ['00154462', '003703', '2023', '1', '경영자', '미등기', '상근', '전략기획', '계열회사 임원', '2014.09.01 ~', '-']
# ------------------------------------------------------------------------
# [('00105855', '005066', 2023, 1, '이사', '미등기', '상근', '글로벌인사실장(CHO)', '-', '1993.01.01~', '-')]
# [('005066', '최종섭', '1968년02월', '남')]
# [('00105855', '010120', 'LS ELECTRIC', 'KOSPI')]
# ['00105855', '005066', '2023', '1', '이사', '미등기', '상근', '글로벌인사실장(CHO)', '-', '1993.01.01~', '-']
# ------------------------------------------------------------------------
# [('01205842', '005892', 2023, 1, '상무', '미등기', '상근', '제품시험담당', '-', '2019.01월(선임일)', '-')]
# [('005892', '김광민', '1968년06월', '남')]
# [('01205842', '267270', '현대건설기계', 'KOSPI')]
# ['01205842', '005892', '2023', '1', '상무', '미등기', '상근', '중국연구소장', '-', '2019.01월(선임일)', '-']
# ------------------------------------------------------------------------
# [('00616290', '021809', 2023, 1, '이사', '사외이사', '비상근', '사외이사감사위원', '등기임원', '2021.04.01~2023.03.29', '-')]
# [('021809', '신승훈', '1975년03월', '남')]
# [('00616290', '123570', '이엠넷', 'KOSDAQ')]
# ['00616290', '021809', '2023', '1', '이사', '미등기', '상근', '개발부문', '미등기임원', '2023.04.01~현재', '-']
# ------------------------------------------------------------------------

# %%
print(db.run_fetch_with_params("SELECT * FROM executive_list WHERE pid = ?", ["021809"]))
print(db.run_fetch_with_params("SELECT * FROM executive_details WHERE pid = ?", ["021809"]))
print(db.run_fetch_with_params("SELECT * FROM corp WHERE corp_code = ?", ["00616290"]))
# Out:
# [('00616290', '021809', 2023, 1, '이사', '사외이사', '비상근', '사외이사감사위원', '등기임원', '2021.04.01~2023.03.29', '-')]
# [('021809', '신승훈', '1975년03월', '남')]
# [('00616290', '123570', '이엠넷', 'KOSDAQ')]

# %%
print(db.run_fetch("SELECT * FROM corp"))
# Out:
# [('00126380', '005930', '삼성전자', 'KOSPI'), ('01515323', '373220', 'LG에너지솔루션', 'KOSPI'), ('00877059', '207940', '삼성바이오로직스', 'KOSPI'), ('00164779', '000660', 'SK하이닉스', 'KOSPI'), ('00356361', '051910', 'LG화학', 'KOSPI'), ('00126362', '006400', '삼성SDI', 'KOSPI'), ('00164742', '005380', '현대차', 'KOSPI'), ('00266961', '035420', 'NAVER', 'KOSPI'), ('00106641', '000270', '기아', 'KOSPI'), ('00258801', '035720', '카카오', 'KOSPI'), ('00155319', '005490', 'POSCO홀딩스', 'KOSPI'), ('00413046', '068270', '셀트리온', 'KOSPI'), ('00149655', '028260', '삼성물산', 'KOSPI'), ('00688996', '105560', 'KB금융', 'KOSPI'), ('00164788', '012330', '현대모비스', 'KOSPI'), ('00382199', '055550', '신한지주', 'KOSPI'), ('00631518', '096770', 'SK이노베이션', 'KOSPI'), ('00126256', '032830', '삼성생명', 'KOSPI'), ('00401731', '066570', 'LG전자', 'KOSPI'), ('00181712', '034730', 'SK', 'KOSPI'), ('00159193', '015760', '한국전력', 'KOSPI'), ('00155276', '003670', '포스코케미칼', 'KOSPI'), ('00244455', '033780', 'KT&G', 'KOSPI'), ('00547583', '086790', '하나금융지주', 'KOSPI'), ('00120021', '003550', 'LG', 'KOSPI'), ('01133217', '323410', '카카오뱅크', 'KOSPI'), ('00356370', '051900', 'LG생활건강', 'KOSPI'), ('00102858', '010130', '고려아연', 'KOSPI'), ('00159023', '017670', 'SK텔레콤', 'KOSPI'), ('01390344', '329180', '현대중공업', 'KOSPI'), ('00261443', '036570', '엔씨소프트', 'KOSPI'), ('00159616', '034020', '두산에너빌리티', 'KOSPI'), ('00126371', '009150', '삼성전기', 'KOSPI'), ('00164645', '011200', 'HMM', 'KOSPI'), ('00126186', '018260', '삼성에스디에스', 'KOSPI'), ('00139214', '000810', '삼성화재', 'KOSPI'), ('00138279', '010950', 'S-Oil', 'KOSPI'), ('00554024', '091990', '셀트리온헬스케어', 'KOSDAQ GLOBAL'), ('01160363', '247540', '에코프로비엠', 'KOSDAQ GLOBAL'), ('00190321', '030200', 'KT', 'KOSPI'), ('00113526', '003490', '대한항공', 'KOSPI'), ('01350869', '316140', '우리금융지주', 'KOSPI'), ('00760971', '259960', '크래프톤', 'KOSPI'), ('00162461', '009830', '한화솔루션', 'KOSPI'), ('00583424', '090430', '아모레퍼시픽', 'KOSPI'), ('00149646', '024110', '기업은행', 'KOSPI'), ('01244601', '377300', '카카오페이', 'KOSPI'), ('01204056', '352820', '하이브', 'KOSPI'), ('00398701', '066970', '엘앤에프', 'KOSDAQ GLOBAL'), ('00360595', '086280', '현대글로비스', 'KOSPI'), ('00165413', '011170', '롯데케미칼', 'KOSPI'), ('00105961', '011070', 'LG이노텍', 'KOSPI'), ('00635134', '097950', 'CJ제일제당', 'KOSPI'), ('00878696', '326030', 'SK바이오팜', 'KOSPI'), ('01319899', '302440', 'SK바이오사이언스', 'KOSPI'), ('01568413', '383220', 'F&F', 'KOSPI'), ('00117744', '000060', '메리츠화재', 'KOSPI'), ('00860332', '138040', '메리츠금융지주', 'KOSPI'), ('00904672', '251270', '넷마블', 'KOSPI'), ('01238169', '271560', '오리온', 'KOSPI'), ('00164830', '009540', '한국조선해양', 'KOSPI'), ('00255619', '035250', '강원랜드', 'KOSPI'), ('00309503', '047810', '한국항공우주', 'KOSPI'), ('00231363', '032640', 'LG유플러스', 'KOSPI'), ('01596425', '402340', 'SK스퀘어', 'KOSPI'), ('00159102', '005830', 'DB손해보험', 'KOSPI'), ('01205709', '267250', 'HD현대', 'KOSPI'), ('00126478', '010140', '삼성중공업', 'KOSPI'), ('00435297', '088980', '맥쿼리인프라', 'KOSPI'), ('00105873', '034220', 'LG디스플레이', 'KOSPI'), ('00126308', '028050', '삼성엔지니어링', 'KOSPI'), ('00161125', '018880', '한온시스템', 'KOSPI'), ('00145109', '000100', '유한양행', 'KOSPI'), ('00170558', '021240', '코웨이', 'KOSPI'), ('00145880', '004020', '현대제철', 'KOSPI'), ('00500254', '078930', 'GS', 'KOSPI'), ('00164478', '000720', '현대건설', 'KOSPI'), ('00937324', '161390', '한국타이어앤테크놀로지', 'KOSPI'), ('00163682', '008560', '메리츠증권', 'KOSPI'), ('01386916', '361610', 'SK아이이테크놀로지', 'KOSPI'), ('00111722', '006800', '미래에셋증권', 'KOSPI'), ('00126566', '012450', '한화에어로스페이스', 'KOSPI'), ('00106368', '011780', '금호석유', 'KOSPI'), ('01137383', '293490', '카카오게임즈', 'KOSDAQ GLOBAL'), ('00828497', '128940', '한미약품', 'KOSPI'), ('01263022', '282330', 'BGF리테일', 'KOSPI'), ('01032486', '241560', '두산밥캣', 'KOSPI'), ('00126292', '029780', '삼성카드', 'KOSPI'), ('00164609', '010620', '현대미포조선', 'KOSPI'), ('00139889', '011790', 'SKC', 'KOSPI'), ('00261285', '036460', '한국가스공사', 'KOSPI'), ('00199252', '028300', 'HLB', 'KOSDAQ'), ('00165680', '008770', '호텔신라', 'KOSPI'), ('00120562', '004990', '롯데지주', 'KOSPI'), ('00854997', '1373 ...

# %%
print(db.run_fetch("SELECT * FROM executive_details"))
# Out:
# [('000000', '한종희', '1962년03월', '남'), ('000001', '허은녕', '1964년08월', '남'), ('000002', '유명희', '1967년06월', '여'), ('000003', '경계현', '1963년03월', '남'), ('000004', '노태문', '1968년09월', '남'), ('000005', '박학규', '1964년11월', '남'), ('000006', '이정배', '1967년02월', '남'), ('000007', '김한조', '1956년07월', '남'), ('000008', '김선욱', '1952년12월', '여'), ('000009', '김종훈', '1960년08월', '남'), ('000010', '김준성', '1967년10월', '남'), ('000011', '권영수', '1957년02월', '남'), ('000012', '이방수', '1958년11월', '남'), ('000013', '장성훈', '1979년01월', '남'), ('000014', '장승권', '1969년07월', '남'), ('000015', '장응진', '1968년11월', '남'), ('000016', '정왕모', '1971년10월', '남'), ('000017', '정원희', '1975년09월', '남'), ('000018', '정하상', '1971년01월', '남'), ('000019', '정혁성', '1973년07월', '남'), ('000020', '정회국', '1977년08월', '남'), ('000021', '조상연', '1977년02월', '남'), ('000022', '최대식', '1975년03월', '남'), ('000023', '김수령', '1962년03월', '남'), ('000024', '최상훈', '1972년02월', '남'), ('000025', '최성훈', '1968년12월', '남'), ('000026', '최세호', '1966년06월', '남'), ('000027', '최유라', '1976년12월', '여'), ('000028', '최은아', '1979년11월', '여'), ('000029', '최재용', '1969년10월', '남'), ('000030', '최제원', '1973년01월', '남'), ('000031', '최해원', '1972년01월', '남'), ('000032', '한동훈', '1979년09월', '남'), ('000033', '허양현', '1969년05월', '남'), ('000034', '박진원', '1967년04월', '남'), ('000035', '허연호', '1966년09월', '남'), ('000036', '현오영', '1968년07월', '남'), ('000037', '홍우평', '1963년01월', '남'), ('000038', '홍정진', '1969년01월', '남'), ('000039', '서원준', '1967년10월', '남'), ('000040', '신영준', '1970년06월', '남'), ('000041', '이혁재', '1966년04월', '남'), ('000042', '전수호', '1962년10월', '남'), ('000043', '정근창', '1967년12월', '남'), ('000044', '최석원', '1966년02월', '남'), ('000045', '김근태', '1960년05월', '남'), ('000046', '권봉석', '1963년09월', '남'), ('000047', '김기수', '1969년03월', '남'), ('000048', '김동수', '1960년07월', '남'), ('000049', '노세원', '1967년09월', '남'), ('000050', '변경석', '1972년02월', '남'), ('000051', '성환두', '1965년10월', '남'), ('000052', '손창완', '1970년01월', '남'), ('000053', '이득중', '1961년06월', '남'), ('000054', '이장하', '1968년08월', '남'), ('000055', '장승세', '1973년04월', '남'), ('000056', '정재한', '1968년02월', '남'), ('000057', '이창실', '1964년12월', '남'), ('000058', '조지훈', '1968년11월', '남'), ('000059', '최승돈', '1972년05월', '남'), ('000060', '한웅재', '1970년10월', '남'), ('000061', 'Denny Thiemig', '1980년10월', '남'), ('000062', '강경원', '1974년02월', '남'), ('000063', '강달모', '1975년06월', '남'), ('000064', '강성모', '1972년08월', '남'), ('000065', '강호석', '1965년10월', '남'), ('000066', '구자훈', '1968년08월', '남'), ('000067', '권종훈', '1971년10월', '남'), ('000068', '박진규', '1966년04월', '남'), ('000069', '김경훈', '1972년01월', '남'), ('000070', '김규성', '1968년02월', '남'), ('000071', '김기웅', '1973년11월', '남'), ('000072', '김기태', '1972년02월', '남'), ('000073', '김남호', '1972년10월', '남'), ('000074', '김민교', '1968년03월', '남'), ('000075', '김범재', '1971년12월', '남'), ('000076', '김병수', '1975년07월', '남'), ('000077', '김병습', '1973년01월', '남'), ('000078', '김석구', '1973년12월', '남'), ('000079', '신미남', '1961년12월', '여'), ('000080', '김영득', '1968년10월', '남'), ('000081', '김영훈', '1978년06월', '남'), ('000082', '김장성', '1964년05월', '남'), ('000083', '김재길', '1967년02월', '남'), ('000084', '김정수', '1968년04월', '남'), ('000085', '김제영', '1972년01월', '남'), ('000086', '김종훈', '1972년11월', '남'), ('000087', '김진경', '1973년01월', '여'), ('000088', '김형식', '1973년12월', '남'), ('000089', '나균일', '1966년01월', '남'), ('000090', '여미숙', '1966년02월', '여'), ('000091', '나희관', '1974년02월', '남'), ('000092', '남경현', '1973년05월', '남'), ('000093', '남주현', '1974년08월', '여'), ('000094', '류덕현', '1974년06월', '남'), ('000095', '박재홍', '1975년03월', '남'), ('000096', '박진용', '1970년08월', '남'), ('000097', '박철희', '1970년02월', '남'), ('000098', '박필규', '1973년12월', '남'), ('000099', '성기은', '1976년01월', '남'), ('000100', '손춘기', '1969년03월', '남'), ('000101', '한승수', '1970년02월', '남'), ('000102', '송무강', '1972년03월', '남'), ('000103', '송준혁', '1974년07월', '남'), ('000104', '송찬규', '1973년03월', '남'), ('000105', '신기창', '1972년04월', '남'), ('000106', '신동환', '1970년09월', '남'), ('000107', '신용인', '1969년11월', '남'), ('000108', '신장환', '1971년08월', '남'), ('000109', '신준영', '1975년05월', '남'), ('000110', '안민규', '1968년10월', ...

# %%
db.commit_connection()
db.close_connection()

# %% [markdown]
# ## Add Datas

# %%
db = DB("dart_corp.db")
db.open_connection()

folder_path = "../data"
year = 2023
quarter = 1
exctv_file_name = f"2021_2022-상장사-drop_dup-{2023}년도-{1}분기.csv"
corp_file_name = f"2021_2022-상장사-drop_dup.csv"
exctv_file_path = os.path.join(folder_path, exctv_file_name)
corp_file_path = os.path.join(folder_path, corp_file_name)

drop_cols = ['발행주식총수', '시가총액', '종가', '연도']
exctv_df = pd.read_csv(exctv_file_path, encoding='utf-8', dtype=object).drop(columns=drop_cols)
exctv_df['기간'] = str(year) + "_" + str(quarter) 
corp_df = pd.read_csv(corp_file_path, encoding='utf-8', dtype=object, index_col=0).drop(columns=['연도'])

# %%
insert_query_exc_list = '''INSERT INTO executive_list
                        (corp_code, pid, year, quarter, position, 
                        registration, full_time, job, relationship_with_shareholder, 
                        employ_duration, expire_date) 
                        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)'''
